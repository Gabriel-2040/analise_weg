# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
# !pip install openpyxl
# !pip install --upgrade ipykernel matplotlib-inline

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import json
import os
import openpyxl
from pathlib import Path

# %%
#df = pd.read_excel(r"E:\PYTHON\PROJETOS_PESSOAIS\analise_weg\_02_DATASETS\datasets_originais\Balanço Patrimonial (BP).xlsx", header = 1)
#df = pd.read_excel(r"E:\PYTHON\PROJETOS_PESSOAIS\analise_weg\_02_DATASETS\datasets_originais\Demonstração de Fluxo de Caixa (DFC).xlsx", header = 1)
df = pd.read_excel(r"/media/hd465gb_backup/PYTHON/PROJETOS_PESSOAIS/analise_weg/_02_DATASETS/datasets_original/Demonstração de Resultados (DRE).xlsx", header = 1)

# %%
df.head()
# Out:
#   Código da Conta                      Descrição da Conta  \
# 0            3.01  Receita de Venda de Bens e/ou Serviços
# 1            3.02   Custo dos Bens e/ou Serviços Vendidos
# 2            3.03                         Resultado Bruto
# 3            3.04          Despesas/Receitas Operacionais
# 4         3.04.01                     Despesas com Vendas
#
#    2010-03-31 00:00:00  2010-06-30 00:00:00  2010-09-30 00:00:00  \
# 0             931907.0            1013015.0            1188622.0
# 1            -623294.0            -703203.0            -811395.0
# 2             308613.0             309812.0             377227.0
# 3            -169009.0            -180123.0            -210590.0
# 4             -93055.0            -100257.0            -121602.0
#
#    2010-12-31 00:00:00  2011-03-31 00:00:00  2011-06-30 00:00:00  \
# 0            1258429.0            1126117.0            1277258.0
# 1            -867129.0            -815455.0            -895821.0
# ...

# %%
df.tail()
# Out:
#                                       Código da Conta  \
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35  Nota: (*) Os valores de Lucro por Ação estão a...
#
#                                    Descrição da Conta  2010-03-31 00:00:00  \
# 31          Média ponderada de ações ordinárias (Mil)             620905.0
# 32                                                NaN                  NaN
# 33  Média ponderada de ações ordinárias potenciais...             620905.0
# 34                                                NaN                  NaN
# 35                                                NaN                  NaN
#
#     2010-06-30 00:00:00  2010-09-30 00:00:00  2010-12-31 00:00:00  \
# 31             620905.0             620905.0             620905.0
# ...

# %%
df_tradado = pd.read_csv(r"E:\PYTHON\PROJETOS_PESSOAIS\analise_weg\_03_ANALISE_EXPLORATORIA\dataset_tradado\Balanco_Patrimonial_tratado.csv")
df.head()
# Out:
#   Código da Conta             Descrição da Conta  2010-03-31 00:00:00  \
# 0               1                    Ativo Total            6417038.0
# 1            1.01               Ativo Circulante            3803788.0
# 2         1.01.01  Caixa e Equivalentes de Caixa              79936.0
# 3      1.01.01.01                Caixas e Bancos                  0.0
# 4      1.01.01.02         Aplicações Financeiras                  0.0
#
#    2010-06-30 00:00:00  2010-09-30 00:00:00  2010-12-31 00:00:00  \
# 0            7343910.0            7365112.0            7511164.0
# 1            4591996.0            4628280.0            4794009.0
# 2              86583.0              59937.0            2552996.0
# 3                  0.0                  0.0              53971.0
# 4                  0.0                  0.0            2499025.0
#
#    2011-03-31 00:00:00  2011-06-30 00:00:00  2011-09-30 00:00:00  \
# 0            7424388.0            7979509.0            8695827.0
# ...
